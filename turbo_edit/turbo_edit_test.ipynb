# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')

# Clone repository
# !git clone https://github.com/chenchenhou/Image-Editing-In-Fashion-Industry.git
# %cd Image-Editing-In-Fashion-Industry

# Setup data
# !mkdir data
# !cp /content/drive/MyDrive/Final_Project/data/editing_data_turbo.json ./data/
# !cp /content/drive/MyDrive/Final_Project/data/images.zip ./data/
# %cd data
# !unzip images.zip
# !mv editing_data_turbo.json ./images/
# %cd ..
# %cd ..
# !rm -rf /content/Image-Editing-In-Fashion-Industry/data/__MACOSX
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: images/image57444.jpg
#   inflating: __MACOSX/images/._image57444.jpg
#   inflating: images/image8347.jpg
#   inflating: __MACOSX/images/._image8347.jpg
#   inflating: images/image66841.jpg
#   inflating: __MACOSX/images/._image66841.jpg
#   inflating: images/image58777.jpg
#   inflating: __MACOSX/images/._image58777.jpg
#   inflating: images/image77794.jpg
#   inflating: __MACOSX/images/._image77794.jpg
#   inflating: images/image20814.jpg
#   inflating: __MACOSX/images/._image20814.jpg
#   inflating: images/image40138.jpg
#   inflating: __MACOSX/images/._image40138.jpg
#   inflating: images/image115177.jpg
#   inflating: __MACOSX/images/._image115177.jpg
#   inflating: images/image112618.jpg
#   inflating: __MACOSX/images/._image112618.jpg
#   inflating: images/image47657.jpg
#   inflating: __MACOSX/images/._image47657.jpg
#   inflating: images/image79961.jpg
#   inflating: __MACOSX/images/._image79961.jpg
# ...

# %%
# Setup turbo edit requirements
# !pip install -r /content/Image-Editing-In-Fashion-Industry/turbo_edit/requirements.txt
# !pip install huggingface_hub==0.24.7
# !pip install torchvision==0.19.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 66.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 32.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.1/315.1 kB 19.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 76.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 54.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 34.4 MB/s eta 0:00:00
# ...

# %%
# Run turbo edit
# %cd /content/Image-Editing-In-Fashion-Industry/turbo_edit
# !python main.py --prompts_file="../data/images/editing_data_turbo.json"
# Out:
# /content/Image-Editing-In-Fashion-Industry/turbo_edit
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2024-11-13 22:42:46.416408: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-13 22:42:46.744129: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-13 22:42:46.821872: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
